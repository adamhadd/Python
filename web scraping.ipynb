# %%
import requests

# %%
n = requests.get("https://fr.wikipedia.org/wiki/Maroc")

# %%
n.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-toc-available" lang="fr" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Maroc \xe2\x80\x94 Wikip\xc3\xa9dia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-fea
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(n.content,"html")

# %%
soup.select_one("#firstHeading").text
# Out:
# 'Maroc'

# %%
soup.select("#mw-content-text>div>p")
# Out:
# [<p class="mw-empty-elt">
#  </p>,
# ...

# %%
for a in soup.select("#mw-content-text>div a"):
    lien = a.get("href")
    if lien .startswith("/wiki"):
        print (lien)
# Out:
# /wiki/Aide:Homonymie
# /wiki/Maroc_(homonymie)
# /wiki/Fichier:Tifinagh_in_Tifinagh.svg
# /wiki/Tifinagh
# /wiki/Aide:Unicode
# /wiki/Wikip%C3%A9dia:Unicode/Test#Alphabet_tifinaghe
# /wiki/Fichier:Flag_of_Morocco.svg
# /wiki/Drapeau_du_Maroc
# /wiki/Fichier:%D8%B4%D8%B9%D8%A7%D8%B1_%D8%A7%D9%84%D9%86%D8%A8%D8%A7%D9%84%D8%A9_%D8%A7%D9%84%D9%85%D8%BA%D8%B1%D8%A8.png
# /wiki/Armoiries_du_Maroc
# /wiki/Liste_des_devises_nationales
# /wiki/Arabe
# /wiki/Amazighe_standard_marocain
# /wiki/Hymne_national
# /wiki/Amazighe_standard_marocain
# /wiki/Arabe
# /wiki/Hymne_national_(Maroc)
# /wiki/F%C3%AAte_nationale
# /wiki/F%C3%AAte_du_Tr%C3%B4ne_(Maroc)
# /wiki/Mohammed_VI
# /wiki/Sahara_occidental
# /wiki/Sahara_espagnol
# /wiki/Liste_des_territoires_non_autonomes_selon_l%27Organisation_des_Nations_unies
# /wiki/Organisation_des_Nations_unies
# /wiki/Organisation_territoriale_du_Maroc
# /wiki/Front_Polisario
# /wiki/Monarchie
# /wiki/Monarchie_constitutionnelle
# /wiki/Parlement_du_Maroc
# ...
